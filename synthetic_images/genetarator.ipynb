# %%
# %cd E:\Pipeline\test_etiquetas\stylegan3
# Out:
# E:\Pipeline\test_etiquetas\stylegan3
# C:\Users\benig\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_0 \
    --class=0 \
    --trunc=0.75 \
    --seeds=0-4999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 0 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1 (1/5000) ...
# Generating image for seed 2 (2/5000) ...
# Generating image for seed 3 (3/5000) ...
# Generating image for seed 4 (4/5000) ...
# Generating image for seed 5 (5/5000) ...
# Generating image for seed 6 (6/5000) ...
# Generating image for seed 7 (7/5000) ...
# Generating image for seed 8 (8/5000) ...
# Generating image for seed 9 (9/5000) ...
# Generating image for seed 10 (10/5000) ...
# Generating image for seed 11 (11/5000) ...
# Generating image for seed 12 (12/5000) ...
# Generating image for seed 13 (13/5000) ...
# Generating image for seed 14 (14/5000) ...
# Generating image for seed 15 (15/5000) ...
# Generating image for seed 16 (16/5000) ...
# Generating image for seed 17 (17/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_1 \
    --class=1 \
    --trunc=0.75 \
    --seeds=100000-104999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# c:\Users\benig\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\utils\cpp_extension.py:1964: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# Generating image for seed 100000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 100001 (1/5000) ...
# Generating image for seed 100002 (2/5000) ...
# Generating image for seed 100003 (3/5000) ...
# Generating image for seed 100004 (4/5000) ...
# Generating image for seed 100005 (5/5000) ...
# Generating image for seed 100006 (6/5000) ...
# Generating image for seed 100007 (7/5000) ...
# Generating image for seed 100008 (8/5000) ...
# Generating image for seed 100009 (9/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_2 \
    --class=2 \
    --trunc=0.75 \
    --seeds=200000-204999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 200000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 200001 (1/5000) ...
# Generating image for seed 200002 (2/5000) ...
# Generating image for seed 200003 (3/5000) ...
# Generating image for seed 200004 (4/5000) ...
# Generating image for seed 200005 (5/5000) ...
# Generating image for seed 200006 (6/5000) ...
# Generating image for seed 200007 (7/5000) ...
# Generating image for seed 200008 (8/5000) ...
# Generating image for seed 200009 (9/5000) ...
# Generating image for seed 200010 (10/5000) ...
# Generating image for seed 200011 (11/5000) ...
# Generating image for seed 200012 (12/5000) ...
# Generating image for seed 200013 (13/5000) ...
# Generating image for seed 200014 (14/5000) ...
# Generating image for seed 200015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_3 \
    --class=3 \
    --trunc=0.6 \
    --seeds=300000-304999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 300000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 300001 (1/5000) ...
# Generating image for seed 300002 (2/5000) ...
# Generating image for seed 300003 (3/5000) ...
# Generating image for seed 300004 (4/5000) ...
# Generating image for seed 300005 (5/5000) ...
# Generating image for seed 300006 (6/5000) ...
# Generating image for seed 300007 (7/5000) ...
# Generating image for seed 300008 (8/5000) ...
# Generating image for seed 300009 (9/5000) ...
# Generating image for seed 300010 (10/5000) ...
# Generating image for seed 300011 (11/5000) ...
# Generating image for seed 300012 (12/5000) ...
# Generating image for seed 300013 (13/5000) ...
# Generating image for seed 300014 (14/5000) ...
# Generating image for seed 300015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_4 \
    --class=4 \
    --trunc=0.75 \
    --seeds=400000-404999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 400000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 400001 (1/5000) ...
# Generating image for seed 400002 (2/5000) ...
# Generating image for seed 400003 (3/5000) ...
# Generating image for seed 400004 (4/5000) ...
# Generating image for seed 400005 (5/5000) ...
# Generating image for seed 400006 (6/5000) ...
# Generating image for seed 400007 (7/5000) ...
# Generating image for seed 400008 (8/5000) ...
# Generating image for seed 400009 (9/5000) ...
# Generating image for seed 400010 (10/5000) ...
# Generating image for seed 400011 (11/5000) ...
# Generating image for seed 400012 (12/5000) ...
# Generating image for seed 400013 (13/5000) ...
# Generating image for seed 400014 (14/5000) ...
# Generating image for seed 400015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_5 \
    --class=5 \
    --trunc=0.75 \
    --seeds=500000-504999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 500000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 500001 (1/5000) ...
# Generating image for seed 500002 (2/5000) ...
# Generating image for seed 500003 (3/5000) ...
# Generating image for seed 500004 (4/5000) ...
# Generating image for seed 500005 (5/5000) ...
# Generating image for seed 500006 (6/5000) ...
# Generating image for seed 500007 (7/5000) ...
# Generating image for seed 500008 (8/5000) ...
# Generating image for seed 500009 (9/5000) ...
# Generating image for seed 500010 (10/5000) ...
# Generating image for seed 500011 (11/5000) ...
# Generating image for seed 500012 (12/5000) ...
# Generating image for seed 500013 (13/5000) ...
# Generating image for seed 500014 (14/5000) ...
# Generating image for seed 500015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_6 \
    --class=6 \
    --trunc=0.6 \
    --seeds=600000-604999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 600000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 600001 (1/5000) ...
# Generating image for seed 600002 (2/5000) ...
# Generating image for seed 600003 (3/5000) ...
# Generating image for seed 600004 (4/5000) ...
# Generating image for seed 600005 (5/5000) ...
# Generating image for seed 600006 (6/5000) ...
# Generating image for seed 600007 (7/5000) ...
# Generating image for seed 600008 (8/5000) ...
# Generating image for seed 600009 (9/5000) ...
# Generating image for seed 600010 (10/5000) ...
# Generating image for seed 600011 (11/5000) ...
# Generating image for seed 600012 (12/5000) ...
# Generating image for seed 600013 (13/5000) ...
# Generating image for seed 600014 (14/5000) ...
# Generating image for seed 600015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_7 \
    --class=7 \
    --trunc=0.6 \
    --seeds=700000-704999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 700000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 700001 (1/5000) ...
# Generating image for seed 700002 (2/5000) ...
# Generating image for seed 700003 (3/5000) ...
# Generating image for seed 700004 (4/5000) ...
# Generating image for seed 700005 (5/5000) ...
# Generating image for seed 700006 (6/5000) ...
# Generating image for seed 700007 (7/5000) ...
# Generating image for seed 700008 (8/5000) ...
# Generating image for seed 700009 (9/5000) ...
# Generating image for seed 700010 (10/5000) ...
# Generating image for seed 700011 (11/5000) ...
# Generating image for seed 700012 (12/5000) ...
# Generating image for seed 700013 (13/5000) ...
# Generating image for seed 700014 (14/5000) ...
# Generating image for seed 700015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_8 \
    --class=8 \
    --trunc=0.6 \
    --seeds=800000-804999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 800000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 800001 (1/5000) ...
# Generating image for seed 800002 (2/5000) ...
# Generating image for seed 800003 (3/5000) ...
# Generating image for seed 800004 (4/5000) ...
# Generating image for seed 800005 (5/5000) ...
# Generating image for seed 800006 (6/5000) ...
# Generating image for seed 800007 (7/5000) ...
# Generating image for seed 800008 (8/5000) ...
# Generating image for seed 800009 (9/5000) ...
# Generating image for seed 800010 (10/5000) ...
# Generating image for seed 800011 (11/5000) ...
# Generating image for seed 800012 (12/5000) ...
# Generating image for seed 800013 (13/5000) ...
# Generating image for seed 800014 (14/5000) ...
# Generating image for seed 800015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_9 \
    --class=9 \
    --trunc=0.6 \
    --seeds=900000-904999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 900000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 900001 (1/5000) ...
# Generating image for seed 900002 (2/5000) ...
# Generating image for seed 900003 (3/5000) ...
# Generating image for seed 900004 (4/5000) ...
# Generating image for seed 900005 (5/5000) ...
# Generating image for seed 900006 (6/5000) ...
# Generating image for seed 900007 (7/5000) ...
# Generating image for seed 900008 (8/5000) ...
# Generating image for seed 900009 (9/5000) ...
# Generating image for seed 900010 (10/5000) ...
# Generating image for seed 900011 (11/5000) ...
# Generating image for seed 900012 (12/5000) ...
# Generating image for seed 900013 (13/5000) ...
# Generating image for seed 900014 (14/5000) ...
# Generating image for seed 900015 (15/5000) ...
# ...

# %%
# !python gen_images.py \
    --outdir=E:\Pipeline\Pipeline_Derma\synthetic_images\imagenes_10 \
    --class=10 \
    --trunc=0.75 \
    --seeds=1000000-1004999 \
    --network=E:\Pipeline\network-snapshot-000564.pkl \
    --noise-mode=const
# Out:
# Loading networks from "E:\Pipeline\network-snapshot-000564.pkl"...
# Generating image for seed 1000000 (0/5000) ...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# Generating image for seed 1000001 (1/5000) ...
# Generating image for seed 1000002 (2/5000) ...
# Generating image for seed 1000003 (3/5000) ...
# Generating image for seed 1000004 (4/5000) ...
# Generating image for seed 1000005 (5/5000) ...
# Generating image for seed 1000006 (6/5000) ...
# Generating image for seed 1000007 (7/5000) ...
# Generating image for seed 1000008 (8/5000) ...
# Generating image for seed 1000009 (9/5000) ...
# Generating image for seed 1000010 (10/5000) ...
# Generating image for seed 1000011 (11/5000) ...
# Generating image for seed 1000012 (12/5000) ...
# Generating image for seed 1000013 (13/5000) ...
# Generating image for seed 1000014 (14/5000) ...
# Generating image for seed 1000015 (15/5000) ...
# ...
