# %%
# !python gen_images.py \
    --outdir=images_0 \
    --class= 0 \
    --trunc=0,85 \
    --seeds=0-3999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_1 \
    --class= 1 \
    --trunc=0,85 \
    --seeds=100000-103999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_2 \
    --class= 2 \
    --trunc=0,85 \
    --seeds=200000-203999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_3 \
    --class= 3 \
    --trunc=300000-303999 \
    --seeds=2 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_4 \
    --class= 4 \
    --trunc=0,85 \
    --seeds=400000-403999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_5 \
    --class= 5 \
    --trunc=0,85 \
    --seeds=500000-503999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_6 \
    --class= 6 \
    --trunc=0,85 \
    --seeds=600000-603999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_7 \
    --class= 7 \
    --trunc=0,85 \
    --seeds=700000-703999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_8 \
    --class= 8 \
    --trunc=0,85 \
    --seeds=800000-803999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_9 \
    --class= 9 \
    --trunc=0,85 \
    --seeds=900000-903999 \
    --network= \
    --noise-mode=const

# %%
# !python gen_images.py \
    --outdir=images_10 \
    --class= 10 \
    --trunc=0,85 \
    --seeds=1000000-1003999 \
    --network= \
    --noise-mode=const
